# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # DATASET 1 (Pre-processing)

# %%
ds1 = pd.read_csv('data_1.csv')

# %% [markdown]
#  Above code is loading data from a CSV file into a format that makes it easier to analyze and manipulate the data using pandas.

# %%
ds1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %% [markdown]
#  From .info(), we can see the data types, count, no of null/non-null values and many more.

# %%
ds1.head(8)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
# 5        6  01-01-2011       1   0     1   5    False        6           2
# 6        7  01-01-2011       1   0     1   6    False        6           1
# 7        8  01-01-2011       1   0     1   7    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24
# 5  0.24
# 6  0.22
# 7  0.20

# %% [markdown]
# .head() shows the top 5 rows if we have not given any specific no. of desired rows.

# %%
ds1.tail(8)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 602      603  28-01-2011       1   0     1   8    False        5           2
# 603      604  28-01-2011       1   0     1   9    False        5           3
# 604      605  28-01-2011       1   0     1  10    False        5           3
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 602  0.16
# 603  0.18
# 604  0.18
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %% [markdown]
# .tail() shows the bottom 5 rows if we have not given any specific no. of desired rows.

# %%
ds1 = ds1.rename(columns={"dteday":"Date","season":"Season","mnth":"Month","hr":"Hour","holiday":"Holiday","weekday":"Weekdays","weathersit":"Weather-situation","temp":"Temperature"})

ds1
# Out:
#      instant        Date  Season  yr  Month  Hour  Holiday  Weekdays  \
# 0          1  01-01-2011       1   0      1     0    False         6
# 1          2  01-01-2011       1   0      1     1    False         6
# 2          3  01-01-2011       1   0      1     2    False         6
# 3          4  01-01-2011       1   0      1     3    False         6
# 4          5  01-01-2011       1   0      1     4    False         6
# ..       ...         ...     ...  ..    ...   ...      ...       ...
# 605      606  28-01-2011       1   0      1    11    False         5
# 606      607  28-01-2011       1   0      1    12    False         5
# 607      608  28-01-2011       1   0      1    13    False         5
# 608      609  28-01-2011       1   0      1    14    False         5
# 609      610  28-01-2011       1   0      1    15    False         5
#
#      Weather-situation  Temperature
# 0                    1         0.24
# 1                    1         0.22
# ...

# %% [markdown]
#  In Above code, I have used .rename for changing column names so that it looks more attractive.

# %%
ds1.isnull().sum()
# Out:
# instant              0
# Date                 0
# Season               0
# yr                   0
# Month                0
# Hour                 0
# Holiday              0
# Weekdays             0
# Weather-situation    0
# Temperature          0
# dtype: int64

# %% [markdown]
# From Above code, we are looking for any null values but here is no null value.

# %%
ds1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# It shows the duplicate values.

# %%
ds1.describe()
# Out:
#           instant  Season     yr  Month        Hour    Weekdays  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000
#
#        Weather-situation  Temperature
# count         610.000000   610.000000
# mean            1.477049     0.196885
# std             0.643496     0.081304
# min             1.000000     0.020000
# 25%             1.000000     0.160000
# 50%             1.000000     0.200000
# 75%             2.000000     0.235000
# max             4.000000     0.460000

# %% [markdown]
#  From Above code, we can find the count,mean,std and many more as you can see.

# %%
ds1.drop('yr',axis=1, inplace=True)

# %% [markdown]
#  In Above, I have dropped year because it has only 0 values.

# %%
season_name = {1:'Spring',2:'Summer',3:'Fall',4:'Winter'}
ds1['Season'] = ds1['Season'].map(season_name)

weather_sit = {1:'Clear',2:'Mist',3:'Light Snow',4:'Heavy Rain'}
ds1['Weather-situation'] = ds1['Weather-situation'].map(weather_sit)

ds1
# Out:
#      instant        Date  Season  Month  Hour  Holiday  Weekdays  \
# 0          1  01-01-2011  Spring      1     0    False         6
# 1          2  01-01-2011  Spring      1     1    False         6
# 2          3  01-01-2011  Spring      1     2    False         6
# 3          4  01-01-2011  Spring      1     3    False         6
# 4          5  01-01-2011  Spring      1     4    False         6
# ..       ...         ...     ...    ...   ...      ...       ...
# 605      606  28-01-2011  Spring      1    11    False         5
# 606      607  28-01-2011  Spring      1    12    False         5
# 607      608  28-01-2011  Spring      1    13    False         5
# 608      609  28-01-2011  Spring      1    14    False         5
# 609      610  28-01-2011  Spring      1    15    False         5
#
#     Weather-situation  Temperature
# 0               Clear         0.24
# 1               Clear         0.22
# 2               Clear         0.22
# 3               Clear         0.24
# ...

# %% [markdown]
#  In Project report, details are given for Season and Weather-situation so I have just updated it here with the use of above code.
#  Now It looks more clear to understand.

# %%
ds1
# Out:
#      instant        Date  Season  Month  Hour  Holiday  Weekdays  \
# 0          1  01-01-2011  Spring      1     0    False         6
# 1          2  01-01-2011  Spring      1     1    False         6
# 2          3  01-01-2011  Spring      1     2    False         6
# 3          4  01-01-2011  Spring      1     3    False         6
# 4          5  01-01-2011  Spring      1     4    False         6
# ..       ...         ...     ...    ...   ...      ...       ...
# 605      606  28-01-2011  Spring      1    11    False         5
# 606      607  28-01-2011  Spring      1    12    False         5
# 607      608  28-01-2011  Spring      1    13    False         5
# 608      609  28-01-2011  Spring      1    14    False         5
# 609      610  28-01-2011  Spring      1    15    False         5
#
#     Weather-situation  Temperature
# 0               Clear         0.24
# 1               Clear         0.22
# 2               Clear         0.22
# 3               Clear         0.24
# ...

# %%
def fahrn_to_clsius(x):
    value = (x-32) * 5/9
    return value

ds1['Temperature'] = ds1['Temperature'].apply(fahrn_to_clsius)

ds1
# Out:
#      instant        Date  Season  Month  Hour  Holiday  Weekdays  \
# 0          1  01-01-2011  Spring      1     0    False         6
# 1          2  01-01-2011  Spring      1     1    False         6
# 2          3  01-01-2011  Spring      1     2    False         6
# 3          4  01-01-2011  Spring      1     3    False         6
# 4          5  01-01-2011  Spring      1     4    False         6
# ..       ...         ...     ...    ...   ...      ...       ...
# 605      606  28-01-2011  Spring      1    11    False         5
# 606      607  28-01-2011  Spring      1    12    False         5
# 607      608  28-01-2011  Spring      1    13    False         5
# 608      609  28-01-2011  Spring      1    14    False         5
# 609      610  28-01-2011  Spring      1    15    False         5
#
#     Weather-situation  Temperature
# 0               Clear   -17.644444
# 1               Clear   -17.655556
# 2               Clear   -17.655556
# 3               Clear   -17.644444
# ...

# %% [markdown]
# In Above code, I have changed Temperature data from Fahrenheit to Celsius as per data requires.

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   instant            610 non-null    int64
#  1   Date               610 non-null    object
#  2   Season             610 non-null    object
#  3   Month              610 non-null    int64
#  4   Hour               610 non-null    int64
#  5   Holiday            610 non-null    bool
#  6   Weekdays           610 non-null    int64
#  7   Weather-situation  610 non-null    object
#  8   Temperature        610 non-null    float64
# dtypes: bool(1), float64(1), int64(4), object(3)
# memory usage: 38.8+ KB

# %%
ds1
# Out:
#      instant        Date  Season  Month  Hour  Holiday  Weekdays  \
# 0          1  01-01-2011  Spring      1     0    False         6
# 1          2  01-01-2011  Spring      1     1    False         6
# 2          3  01-01-2011  Spring      1     2    False         6
# 3          4  01-01-2011  Spring      1     3    False         6
# 4          5  01-01-2011  Spring      1     4    False         6
# ..       ...         ...     ...    ...   ...      ...       ...
# 605      606  28-01-2011  Spring      1    11    False         5
# 606      607  28-01-2011  Spring      1    12    False         5
# 607      608  28-01-2011  Spring      1    13    False         5
# 608      609  28-01-2011  Spring      1    14    False         5
# 609      610  28-01-2011  Spring      1    15    False         5
#
#     Weather-situation  Temperature
# 0               Clear   -17.644444
# 1               Clear   -17.655556
# 2               Clear   -17.655556
# 3               Clear   -17.644444
# ...

# %% [markdown]
# ## VISUALISATIONS (Pie Chart + Line Plot)

# %%
columns = ['Hour','Holiday','Weekdays','Weather-situation',]

plt.figure(figsize=(12,18))
for i, column in enumerate(columns,1):
    plt.subplot(3,3,i)
    data = ds1[column].value_counts()
    plt.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('husl',len(data)))
    plt.title(f'Pie Chart of {column}')
    
    
plt.tight_layout()
plt.show()

# %% [markdown]
#  PIE CHART
#
#  Above I have used Pie Chart to represent the ratio of data insights.
#
# 1.Hour - An average 4 % ,each from 0 to 12 Hour has.
#
# 2.Holiday - As we can see, around 96% there is no holiday.
#
# 3.Weekdays - Clearly with the help of Pie chart it is showing that every weekdays shared an average same amount of ratio.
#
# 4.Weather-sit - Clear weather is around 60% and Mist is around 32%.

# %%
ds1.head(5)
# Out:
#    instant        Date  Season  Month  Hour  Holiday  Weekdays  \
# 0        1  01-01-2011  Spring      1     0    False         6
# 1        2  01-01-2011  Spring      1     1    False         6
# 2        3  01-01-2011  Spring      1     2    False         6
# 3        4  01-01-2011  Spring      1     3    False         6
# 4        5  01-01-2011  Spring      1     4    False         6
#
#   Weather-situation  Temperature
# 0             Clear   -17.644444
# 1             Clear   -17.655556
# 2             Clear   -17.655556
# 3             Clear   -17.644444
# 4             Clear   -17.644444

# %% [markdown]
# LINE PLOT

# %%
sns.lineplot(x='Date', y='Temperature', data=ds1)
plt.title('Temperature over Date')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  LINE PLOT
#
#  Here It is showing that Temperature is continuously changing as Date changes.

# %% [markdown]
# # DATASET 2 (Pre-processing)

# %%
ds2 = pd.read_csv('data_2.csv')

# %% [markdown]
# Above code is loading data from a CSV file into a format that makes it easier to analyze and manipulate the data using pandas.

# %%
ds2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
ds2 = ds2.rename(columns={"atemp":"Atemp","hum":"Humidity","windspeed":"Windspeed","casual":"Casual","registered":"Registered","cnt":"Total Count"})

ds2
# Out:
#      Unnamed: 0  instant   Atemp  Humidity  Windspeed  Casual  Registered  \
# 0             0        1  0.2879      0.81     0.0000       3          13
# 1             1        2  0.2727      0.80     0.0000       8          32
# 2             2        3  0.2727      0.80     0.0000       5          27
# 3             3        4  0.2879      0.75     0.0000       3          10
# 4             4        5  0.2879      0.75     0.0000       0           1
# ..          ...      ...     ...       ...        ...     ...         ...
# 605         605      606  0.2121      0.93     0.1045       0          30
# 606         606      607  0.2121      0.93     0.1045       1          28
# 607         607      608  0.2121      0.93     0.1045       0          31
# 608         608      609  0.2727      0.80     0.0000       2          36
# 609         609      610  0.2576      0.86     0.0000       1          40
#
#      Total Count
# 0             16
# 1             40
# 2             32
# ...

# %% [markdown]
# In Above code, I have used .rename for changing column names so that it looks more attractive.

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   610 non-null    int64
#  1   instant      610 non-null    int64
#  2   Atemp        599 non-null    float64
#  3   Humidity     610 non-null    float64
#  4   Windspeed    610 non-null    float64
#  5   Casual       610 non-null    int64
#  6   Registered   610 non-null    int64
#  7   Total Count  610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.2 KB

# %% [markdown]
# From .info(), we can see the data types, count, no of null/non-null values and many more.

# %%
ds2.head(9)
# Out:
#    Unnamed: 0  instant   Atemp  Humidity  Windspeed  Casual  Registered  \
# 0           0        1  0.2879      0.81     0.0000       3          13
# 1           1        2  0.2727      0.80     0.0000       8          32
# 2           2        3  0.2727      0.80     0.0000       5          27
# 3           3        4  0.2879      0.75     0.0000       3          10
# 4           4        5  0.2879      0.75     0.0000       0           1
# 5           5        6  0.2576      0.75     0.0896       0           1
# 6           6        7  0.2727      0.80     0.0000       2           0
# 7           7        8  0.2576      0.86     0.0000       1           2
# 8           8        9     NaN      0.75     0.0000       1           7
#
#    Total Count
# 0           16
# 1           40
# 2           32
# 3           13
# 4            1
# 5            1
# 6            2
# 7            3
# 8            8

# %% [markdown]
#  .head() shows the top 5 rows if we have not given any specific no. of required rows.

# %%
ds2.tail(9)
# Out:
#      Unnamed: 0  instant   Atemp  Humidity  Windspeed  Casual  Registered  \
# 601         601      602  0.1970      0.86     0.0896       2          58
# 602         602      603  0.1970      0.86     0.0896       2         155
# 603         603      604  0.2121      0.86     0.0896       6          95
# 604         604      605  0.2121      0.86     0.1045       0          49
# 605         605      606  0.2121      0.93     0.1045       0          30
# 606         606      607  0.2121      0.93     0.1045       1          28
# 607         607      608  0.2121      0.93     0.1045       0          31
# 608         608      609  0.2727      0.80     0.0000       2          36
# 609         609      610  0.2576      0.86     0.0000       1          40
#
#      Total Count
# 601           60
# 602          157
# 603          101
# 604           49
# 605           30
# 606           29
# 607           31
# 608           38
# 609           41

# %% [markdown]
#  .tail() shows the bottom 5 rows if we have not given any specific no. of required rows.

# %%
ds2.drop('Unnamed: 0',axis=1, inplace=True)
ds2
# Out:
#      instant   Atemp  Humidity  Windspeed  Casual  Registered  Total Count
# 0          1  0.2879      0.81     0.0000       3          13           16
# 1          2  0.2727      0.80     0.0000       8          32           40
# 2          3  0.2727      0.80     0.0000       5          27           32
# 3          4  0.2879      0.75     0.0000       3          10           13
# 4          5  0.2879      0.75     0.0000       0           1            1
# ..       ...     ...       ...        ...     ...         ...          ...
# 605      606  0.2121      0.93     0.1045       0          30           30
# 606      607  0.2121      0.93     0.1045       1          28           29
# 607      608  0.2121      0.93     0.1045       0          31           31
# 608      609  0.2727      0.80     0.0000       2          36           38
# 609      610  0.2576      0.86     0.0000       1          40           41
#
# [610 rows x 7 columns]

# %% [markdown]
#  From Above code, I have dropped a column that was not needed here.

# %%
ds2.isnull().sum()
# Out:
# instant         0
# Atemp          11
# Humidity        0
# Windspeed       0
# Casual          0
# Registered      0
# Total Count     0
# dtype: int64

# %% [markdown]
#  Here I have found out that there is null values in the column Atemp.

# %%
ds2.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  It shows that there is no duplicate values in the given data.

# %%
ds2['Atemp'] = ds2['Atemp'].fillna(ds2['Atemp'].mean())

ds2.isnull().sum()
# Out:
# instant        0
# Atemp          0
# Humidity       0
# Windspeed      0
# Casual         0
# Registered     0
# Total Count    0
# dtype: int64

# %% [markdown]
#  From Above code, I have removed the null values using mean method with the help of .fillna.
#
#  Now there is no null values in the data.

# %%
ds2
# Out:
#      instant   Atemp  Humidity  Windspeed  Casual  Registered  Total Count
# 0          1  0.2879      0.81     0.0000       3          13           16
# 1          2  0.2727      0.80     0.0000       8          32           40
# 2          3  0.2727      0.80     0.0000       5          27           32
# 3          4  0.2879      0.75     0.0000       3          10           13
# 4          5  0.2879      0.75     0.0000       0           1            1
# ..       ...     ...       ...        ...     ...         ...          ...
# 605      606  0.2121      0.93     0.1045       0          30           30
# 606      607  0.2121      0.93     0.1045       1          28           29
# 607      608  0.2121      0.93     0.1045       0          31           31
# 608      609  0.2727      0.80     0.0000       2          36           38
# 609      610  0.2576      0.86     0.0000       1          40           41
#
# [610 rows x 7 columns]

# %%
def fahrn_to_clsius(x):
    value = (x-32) * 5/9
    return value

ds2['Atemp'] = ds2['Atemp'].apply(fahrn_to_clsius)

ds2
# Out:
#      instant      Atemp  Humidity  Windspeed  Casual  Registered  Total Count
# 0          1 -17.617833      0.81     0.0000       3          13           16
# 1          2 -17.626278      0.80     0.0000       8          32           40
# 2          3 -17.626278      0.80     0.0000       5          27           32
# 3          4 -17.617833      0.75     0.0000       3          10           13
# 4          5 -17.617833      0.75     0.0000       0           1            1
# ..       ...        ...       ...        ...     ...         ...          ...
# 605      606 -17.659944      0.93     0.1045       0          30           30
# 606      607 -17.659944      0.93     0.1045       1          28           29
# 607      608 -17.659944      0.93     0.1045       0          31           31
# 608      609 -17.626278      0.80     0.0000       2          36           38
# 609      610 -17.634667      0.86     0.0000       1          40           41
#
# [610 rows x 7 columns]

# %% [markdown]
# In Above code, I have changed Temperature data from Fahrenheit to Celsius as per data requires.

# %% [markdown]
# # VISUALISATIONS (Box Plot + Histogram Plot)

# %%
columns = ['Humidity','Windspeed','Total Count']

plt.figure(figsize=(12,8))


for i,col in enumerate(columns, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=ds2[col], palette='Set2')
    plt.title(f'Box Plot for {col}')
    plt.xlabel(col)
    
plt.tight_layout()
plt.show()

# %% [markdown]
#  BOX PLOT
#
#  Here, I have used Box Plot to represent the numerical data for the Humidity, Windspeed & Total Count.
#
#  It is showing that there is some outliers in Windspeed & Totl Count.

# %% [markdown]
#  HISTOGRAM PLOT

# %%
columns = ['Humidity','Windspeed','Total Count']

plt.figure(figsize=(15, 12))

for i, col in enumerate(columns, 1):
    plt.subplot(2, 3, i)
    sns.histplot(ds2[col], kde=True, bins=20)
    plt.title(f'Histogram Plot showing {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    
plt.tight_layout()
plt.show()

# %% [markdown]
#  This code snippet provides a clear and insightful visualization of the distribution of the three specified columns in above dataset.
#
# Each histogram plot shows the frequency distribution, and the KDE curve gives an idea of the underlying distribution shape.

# %% [markdown]
# # MERGING DATASET 1 & 2 (Pre-processing)

# %%
ds_1_merge_2 = pd.merge(ds1, ds2, on='instant',how='inner')

# %% [markdown]
#  This code merges ds1_update and ds2 based on the instant column, keeping only the rows where instant has matching values in both DataFrames.
#
#  This is useful when you want to combine data from two sources but are only interested in the overlapping records.

# %%
ds_1_merge_2
# Out:
#      instant        Date  Season  Month  Hour  Holiday  Weekdays  \
# 0          1  01-01-2011  Spring      1     0    False         6
# 1          2  01-01-2011  Spring      1     1    False         6
# 2          3  01-01-2011  Spring      1     2    False         6
# 3          4  01-01-2011  Spring      1     3    False         6
# 4          5  01-01-2011  Spring      1     4    False         6
# ..       ...         ...     ...    ...   ...      ...       ...
# 605      606  28-01-2011  Spring      1    11    False         5
# 606      607  28-01-2011  Spring      1    12    False         5
# 607      608  28-01-2011  Spring      1    13    False         5
# 608      609  28-01-2011  Spring      1    14    False         5
# 609      610  28-01-2011  Spring      1    15    False         5
#
#     Weather-situation  Temperature      Atemp  Humidity  Windspeed  Casual  \
# 0               Clear   -17.644444 -17.617833      0.81     0.0000       3
# ...

# %%
ds_1_merge_2.head(2)
# Out:
#    instant        Date  Season  Month  Hour  Holiday  Weekdays  \
# 0        1  01-01-2011  Spring      1     0    False         6
# 1        2  01-01-2011  Spring      1     1    False         6
#
#   Weather-situation  Temperature      Atemp  Humidity  Windspeed  Casual  \
# 0             Clear   -17.644444 -17.617833      0.81        0.0       3
# 1             Clear   -17.655556 -17.626278      0.80        0.0       8
#
#    Registered  Total Count
# 0          13           16
# 1          32           40

# %% [markdown]
# .head() shows the top 5 rows if we have not given any specific no. of required rows.

# %%
ds_1_merge_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 610 entries, 0 to 609
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   instant            610 non-null    int64
#  1   Date               610 non-null    object
#  2   Season             610 non-null    object
#  3   Month              610 non-null    int64
#  4   Hour               610 non-null    int64
#  5   Holiday            610 non-null    bool
#  6   Weekdays           610 non-null    int64
#  7   Weather-situation  610 non-null    object
#  8   Temperature        610 non-null    float64
#  9   Atemp              610 non-null    float64
#  10  Humidity           610 non-null    float64
#  11  Windspeed          610 non-null    float64
#  12  Casual             610 non-null    int64
#  13  Registered         610 non-null    int64
#  14  Total Count        610 non-null    int64
# dtypes: bool(1), float64(4), int64(7), object(3)
# ...

# %% [markdown]
# From .info(), we can see the data types, count, no of null/non-null values and many more.

# %%
ds_1_merge_2.isnull().sum()
# Out:
# instant              0
# Date                 0
# Season               0
# Month                0
# Hour                 0
# Holiday              0
# Weekdays             0
# Weather-situation    0
# Temperature          0
# Atemp                0
# Humidity             0
# Windspeed            0
# Casual               0
# Registered           0
# Total Count          0
# dtype: int64

# %% [markdown]
# From Above code, we are looking for any null values but here is no null value.

# %%
ds_1_merge_2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # VISUALISATIONS (Line Plot)

# %%
sns.lineplot(x='Date', y='Total Count', data=ds_1_merge_2)
plt.title('Effect on Count basis of Date')
plt.xticks(rotation=90)
plt.show()

sns.lineplot(x='Temperature', y='Total Count', data=ds_1_merge_2)
plt.title('Effect on Count basis of Temperature')
plt.xticks(rotation=90)
plt.show()

sns.lineplot(x='Weather-situation', y='Total Count', data=ds_1_merge_2)
plt.title('Effect on Count basis of Weather-situation')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
#  LINE PLOT
#
#  Effect on Count basis of Date - this line plot shows the total count for every single Date.
#
#  Effect on Count basis of Temperature - this line plot shows continuing up and downfall for the Total count on basis of Temperature.
#
#  Effect on Count basis of Weather-situation - Clearly it is showing that for CLEAR weather ,Total count is maximum & for Light Snow,Total Count is minimum.

# %%
ds_1_merge_2.to_csv('data 1 & 2.csv')

# %% [markdown]
#  Now we will transfer this updated CSV file to our storage folder.
